# %%
from kassia import Kassia
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from kassia import Kassia
#
# File ~/Dev/kassia-api/kassia.py:15
#      12 from reportlab.platypus import PageBreak, Paragraph, Spacer
#      14 from builder.complex_doc_template import ComplexDocTemplate
# ---> 15 from builder.coord import Coord
#      16 from builder.drop_cap import Dropcap
#      17 from builder.font_reader import find_and_register_fonts
#
# ModuleNotFoundError: No module named 'builder.coord'
