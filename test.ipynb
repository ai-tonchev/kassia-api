# %%
from kassia_main import Kassia

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

# %%
from reportlab.lib import fontfinder

# %%
t_file = 'tests/chronos_test.xml'

# %%
import io 
bf = io.BytesIO(open(t_file, 'r').read())

# %%
Kassia(bf, 'test.pdf')

# %%
from api import app

# %%
from fastapi.testclient import TestClient

# %%
client = TestClient(app)

# %%
t_file = 'tests/chronos_test.xml'

# %%
response = client.post(
    "/xml-to-pdf",
    files={"file": (t_file, b"<root></root>", "text/xml")}
)

print(response.status_code)
print(response.headers["content-type"])
# print(response.headers["content-disposition"])
print(response.content)  # this is your PDF bytes
# Out:
# 200
# application/pdf
# ...

# %%
import sys
print(sys.executable)
# Out:
# /home/ai-tonchev/anaconda3/bin/python

# %%
# !uvicorn api.main:app --reload --port 8000
# Out:
# INFO:     Will watch for changes in these directories: ['/home/ai-tonchev/Dev/kassia-api']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [64015] using StatReload
# Process SpawnProcess-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3/dist-packages/uvicorn/_subprocess.py", line 78, in subprocess_started
#     target(sockets=sockets)
#   File "/usr/lib/python3/dist-packages/uvicorn/server.py", line 62, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
# ...

# %%
# !sudo apt install uvicorn
# Out:
# [sudo] password for ai-tonchev:
# sudo: a password is required
# ^C
